# %%
s1 = 'prezados, ao tentar efetuar a atualização de versão/scripts na base interna spjmam foi identificado um erro de criação de tabela tsbas2long. o descritivo do erro segue abaixo.  12/07/2019 11:20:37.085        running_db_scripts        spjmam        saj nao foi possivel executar o script -> saj000385.dh4 na base de dados -> spjmam o statement ->         create table saj.esajpesqfin (         cdusuario            char(15) not null,         cdsistema            decimal(5) not null,         bldescricao          clob null,         dtresposta           date not null,         deversao             varchar2(20) null,         fltiporesposta       char(1) null )         tablespace tsbas2dat         lob (bldescricao) store as securefile (tablespace tsbas2long enable storage in row nocache logging) apresentou o seguinte erro -> ora-00959: tablespace tsbas2long não existe  mensagem completa ->         java.sql.sqlsyntaxerrorexception: ora-00959: tablespace tsbas2long não existe  12/07/2019 11:20:37.108   error_analising_scripts        spjmam        saj nao foi possivel executar o script -> saj000385.dh4 na base de dados -> spjmam o statement ->         create table saj.esajpesqfin (         cdusuario            char(15) not null,         cdsistema            decimal(5) not null,         bldescricao          clob null,         dtresposta           date not null,         deversao             varchar2(20) null,         fltiporesposta       char(1) null )         tablespace tsbas2dat         lob (bldescricao) store as securefile (tablespace tsbas2long enable storage in row nocache logging) apresentou o seguinte erro -> ora-00959: tablespace tsbas2long não existe  mensagem completa ->         java.sql.sqlsyntaxerrorexception: ora-00959: tablespace tsbas2long não existe  12/07/2019 11:20:37.122            finished_error                      saj nao foi possivel executar o script -> saj000385.dh4 na base de dados -> spjmam o statement ->         create table saj.esajpesqfin (         cdusuario            char(15) not null,         cdsistema            decimal(5) not null,         bldescricao          clob null,         dtresposta           date not null,         deversao             varchar2(20) null,         fltiporesposta       char(1) null )         tablespace tsbas2dat         lob (bldescricao) store as securefile (tablespace tsbas2long enable storage in row nocache logging) apresentou o seguinte erro -> ora-00959: tablespace tsbas2lon  g não existe  mensagem completa ->         java.sql.sqlsyntaxerrorexception: ora-00959: tablespace tsbas2long não existe'
s2 = 'prezados, a rotina sajintegracoestribunal_ajuizamento localizada no servidor 10.200.11.200, está apresentando o seguinte   erro no retorno do xml:  método:  antesdeinserir     ora-01438: value larger than specified precision allowed for this column;  método: servicoenviomensagenspendentes     -9997|ocorreu o seguinte erro na entidade log mensagens ws: erro não cadastrado do banco de dados. código de erro - nativo: 1438. mensagem do banco - ora-01438: value larger than specified precision allowed for this column entre em contato com o administrador do sistema.;   verifiquei que o último update do sistema, é na tabela epadcodigo:  update    /*+ rule */ saj.epadcodigo  set    nuchave =10126  where     nmtabela =espjwsmensagemlog and    vlchave1=4 and    vlchave2=67076238 and     vlchave3 =  ;  e o último insert antes do erro é justamente na espjwsmensagemlog, tentando inserir apenas o texto banco de dados em manutenção:      insert into saj.espjwsmensagemlog ( cdwebservices ,cdmensagem ,nuseqenvio ,dtprocessamento ,cdretorno ,deretorno ) values ( 4 ,67076238 ,10126 ,to_date(28/11/2016 17:06:28,dd/mm/yyyy hh24:mi:ss) ,92 ,banco de dados em manutenção);  segue anexo o log do erro:      =========================================================================   erro na execução do script sp4000125.dh4  ao executar o script acima ocasionou o erro abaixo:   02/02/2018pdate pdate    /*+ rule */ saj.epadcodigo pdate    /*+ rule */ saj.epadcodigo  set    nuchave =10126  where     nmtabela =espjwsmensagemlog and    vlchave1=4 and set    nuchave =10126  where     nmtabela =espjwsmensagemlog and    vlchave1=4 and   /*+ rule */ saj.epadcodigo  set    nuchave =10126  where     nmtabela =espjwsmensagemlog and    vlchave1=4 and 04:25:52.687         analising_scripts       spjtint        saj capronica3.exe - versao 1.1.22 02/02/2018 04:25:52.691         analising_scripts       spjtint        saj carregando o arquivo c:\capronica3\bin\192.168.226.151\input\spjtint\sp4000125.dh4 02/02/2018 04:25:52.698         analising_scripts       spjtint        saj validando c:\capronica3\bin\192.168.226.151\input\spjtint\sp4000125.dh4 02/02/2018 04:25:52.699         analising_scripts       spjtint        saj ok  02/02/2018 04:26:51.735        running_db_scripts       spjtint        saj capronica3.exe - versao 1.1.22 02/02/2018 04:26:51.741        running_db_scripts       spjtint        saj carregando o arquivo c:\capronica3\bin\192.168.226.151\input\spjtint\sp4000125.dh4 02/02/2018 04:26:51.748        running_db_scripts       spjtint        saj executando c:\capronica3\bin\192.168.226.151\input\spjtint\sp4000125.dh4 02/02/2018 04:26:51.750        running_db_scripts       spjtint        saj progresso: (1/3) 02/02/2018 04:26:51.773        running_db_scripts       spjtint        saj nao foi possivel executar o script sp4000125.dh4 na base spjtint. o statement: insert into saj.epadconfigservidor (deipservidor, denomeaplicativo, dechave, devalor, dedescricao) values (*, *, rpc.controlar_reconexao, false, habilita o controle de reconexão.) apresentou o erro: ora-00001: restrição exclusiva (saj.xpkepadconfigservi) violada  para reproduzir basta executar o script através do caproni na base abaixo:  spjxpsc =    (description =    (address_list =        (address =         (protocol = tcp)         (host = 192.168.226.151)         (port = 1521)        )   )   (connect_data = (sid = spjtint) (server = dedicated)   ) ) '
s3 = 'necessário ajustar script abaixo a fim de atualizar os pacotes que contém esse script. evidência: log.txt  --  script de atualizacao do sistema saj --  todos os direitos reservados a softplan planejamento e sistemas ltda -- -- --  script numero  : pj011107.dh4 --  banco alvo     : oracle --  data de criacao: 08/12/2016 16:45:02 -- -- --  sistema        : pj -- --  autor          : roberto.junior -- --  objetivo: inclusão de nova pesquisa de saida --  nº salt: 230724-1-2 -- -- pré-requisitos: --  not_has(script, pj10494.sql)  insert into    esegpesquisasc    (cdpesquisasc, depesquisasc, nmusuariopsc, desenhapsc,    dtinicio, dtfim, blpesqususistema, blpesqresponsavti,    blpesqgerentesetor, flformularioweb, flpesqentrada) select       (select coalesce(max(cdpesquisasc) + 1, 1) from esegpesquisasc),      notasatisfacaocliente2016, pesqpge,      null, to_date(12/12/2016,dd/mm/yyyy), to_date(16/12/2016,dd/mm/yyyy), null, null, null, n, n from dual where exists      (           select cdcliente from saj.esegcliente where cdcliente in (pgeba)      );    insert into    esegpesqscsistema    (cdpesquisasc, cdsistema) select          (select cdpesquisasc from esegpesquisasc where upper(depesquisasc)          = upper(notasatisfacaocliente2016)), 91 /* código sistema pj */ from dual where exists      (           select cdcliente from saj.esegcliente where cdcliente in (pgeba)      );    insert into saj.epadscriptrodado (nmscript, descript, dtexecucao) values (pj011107.dh4, inclusão de nova pesquisa de saida, sysdate);   '
s4 = 'descrição do problema: cliente: osasco  base: 0055  servidor de aplicação: flnsrvunj4017  versão: 4.23.0-57 módulo: execução fiscal usuário: dlandrade55  ao tentar gerar o kit o sistema retorna a mensagem de erro:  erro: invalid variant type conversion: erro geral na geração de processos a partir de cdas  o erro ocorre apenas com os devedores abaixo  devedor: jose salomao filho  cda:0005810; 0011429; 0014456  devedor: flavio vagner moares da silva cda:002776,0018695,009445,002361,0008726  ---------------------------- segue por anexo log do servidor, video   sql coletado pelo spmonitor   select    prm.*  from     (select        kd.cdkitgeracao,       kd.sgtipodocumento,       kd.nudocumento,       kd.nuseqkitdevgeracao,       kg.flagendado,       kg.flextrajudicial,       ge.cderro as cc_cderro,       ge.dedetalheerro as cc_dedetalheerro,       kd.dtgeracaoproc,       kg.dtvencdocarrec,       kg.cdmodelocorresp,      kg.tpgeracaoprocesso as cc_tpgeracaoprocesso     from       saj.espjkitdevgeracao kd        join saj.espjkitgeracao kg on          kd.cdkitgeracao = kg.cdkitgeracao        left outer join saj.espjgeracaoerro ge on           ge.cdkitgeracao = kd.cdkitgeracao and         ge.nuseqkitdevgeracao = kd.nuseqkitdevgeracao     where       not exists(select cdagendamento     from       saj.espjagendinterromp     where        kg.cdagendamento = cdagendamento ) and    kg.dtcancelamento is null and    kd.cdprocesso is null and    kd.dtgeracaoproc is null and    ge.cderro is null and    kd.flprocessandodev = :pflprocessandodev and    kg.dtfimprocessamento is null and    kd.cdkitgeracao = :prmcdkitgeracao and   kg.flagendado = :pflagendado  order by    kg.dtusuinclusao asc ) prm  where      rownum <= :pnprimeiros params=([pflprocessandodev,ftstring,n][prmcdkitgeracao,ftfloat,419][pflagendado,ftstring,n][pnprimeiros,ftinteger,1])   ************************      local informado pelo cliente: cdas - conferência individual de cdas nome: carla.s celular: 4081    anexo após o envio do portal:  2018-10-30_14h09_26.png      anexo após o envio do portal:  flavio vagner moraes da silva_01 oct. 29 15.49.rar      anexo após o envio do portal:  jose salomao filho_04 oct. 29 16.07.rar      anexo após o envio do portal:  log.ra'

# %%
from gensim.summarization.summarizer import summarize

# %%
s1 = '''Prezados, ao tentar efetuar a atualização de versão/scripts na base interna SPJMAM foi identificado um erro de criação de tabela TSBAS2LONG.
O descritivo do erro segue abaixo.

12/07/2019 11:20:37.085        RUNNING_DB_SCRIPTS        SPJMAM        saj Nao foi possivel executar o script -> SAJ000385.DH4 na base de dados -> SPJMAM
O statement ->
        CREATE TABLE SAJ.ESAJPESQFIN (
        CDUSUARIO            CHAR(15) NOT NULL,
        CDSISTEMA            DECIMAL(5) NOT NULL,
        BLDESCRICAO          CLOB NULL,
        DTRESPOSTA           DATE NOT NULL,
        DEVERSAO             VARCHAR2(20) NULL,
        FLTIPORESPOSTA       CHAR(1) NULL
)
        TABLESPACE TSBAS2DAT
        LOB (BLDESCRICAO) STORE AS SECUREFILE (TABLESPACE TSBAS2LONG ENABLE STORAGE IN ROW NOCACHE LOGGING)
Apresentou o seguinte erro -> ORA-00959: tablespace TSBAS2LONG não existe

Mensagem completa ->
        java.sql.SQLSyntaxErrorException: ORA-00959: tablespace TSBAS2LONG não existe

12/07/2019 11:20:37.108   ERROR_ANALISING_SCRIPTS        SPJMAM        saj Nao foi possivel executar o script -> SAJ000385.DH4 na base de dados -> SPJMAM
O statement ->
        CREATE TABLE SAJ.ESAJPESQFIN (
        CDUSUARIO            CHAR(15) NOT NULL,
        CDSISTEMA            DECIMAL(5) NOT NULL,
        BLDESCRICAO          CLOB NULL,
        DTRESPOSTA           DATE NOT NULL,
        DEVERSAO             VARCHAR2(20) NULL,
        FLTIPORESPOSTA       CHAR(1) NULL
)
        TABLESPACE TSBAS2DAT
        LOB (BLDESCRICAO) STORE AS SECUREFILE (TABLESPACE TSBAS2LONG ENABLE STORAGE IN ROW NOCACHE LOGGING)
Apresentou o seguinte erro -> ORA-00959: tablespace TSBAS2LONG não existe

Mensagem completa ->
        java.sql.SQLSyntaxErrorException: ORA-00959: tablespace TSBAS2LONG não existe

12/07/2019 11:20:37.122            FINISHED_ERROR                      saj Nao foi possivel executar o script -> SAJ000385.DH4 na base de dados -> SPJMAM
O statement ->
        CREATE TABLE SAJ.ESAJPESQFIN (
        CDUSUARIO            CHAR(15) NOT NULL,
        CDSISTEMA            DECIMAL(5) NOT NULL,
        BLDESCRICAO          CLOB NULL,
        DTRESPOSTA           DATE NOT NULL,
        DEVERSAO             VARCHAR2(20) NULL,
        FLTIPORESPOSTA       CHAR(1) NULL
)
        TABLESPACE TSBAS2DAT
        LOB (BLDESCRICAO) STORE AS SECUREFILE (TABLESPACE TSBAS2LONG ENABLE STORAGE IN ROW NOCACHE LOGGING)
Apresentou o seguinte erro -> ORA-00959: tablespace TSBAS2LONG não existe

Mensagem completa ->
        java.sql.SQLSyntaxErrorException: ORA-00959: tablespace TSBAS2LONG não existe'''


print(summarize(s1))
# Out:
# 12/07/2019 11:20:37.085        RUNNING_DB_SCRIPTS        SPJMAM        saj Nao foi possivel executar o script -> SAJ000385.DH4 na base de dados -> SPJMAM
# 12/07/2019 11:20:37.108   ERROR_ANALISING_SCRIPTS        SPJMAM        saj Nao foi possivel executar o script -> SAJ000385.DH4 na base de dados -> SPJMAM
# 12/07/2019 11:20:37.122            FINISHED_ERROR                      saj Nao foi possivel executar o script -> SAJ000385.DH4 na base de dados -> SPJMAM
# Apresentou o seguinte erro -> ORA-00959: tablespace TSBAS2LONG não existe
# Apresentou o seguinte erro -> ORA-00959: tablespace TSBAS2LONG não existe
# Apresentou o seguinte erro -> ORA-00959: tablespace TSBAS2LONG não existe
# java.sql.SQLSyntaxErrorException: ORA-00959: tablespace TSBAS2LONG não existe
# java.sql.SQLSyntaxErrorException: ORA-00959: tablespace TSBAS2LONG não existe

# %%
s2 = '''Prezados,

A atividade 220014/1/5 solicita atualização da base SPJPESHM da PGEES - Homologação, porém ao executar o script PJ09464-X.sql, ocorreu o erro: LOB (BLMENSAGEM) STORE AS SECUREFILE (TABLESPACE TSSPJ1LONG ENABLE STORAGE IN ROW  NOCACHE LOGGING) * ERROR at line 13: ORA-00955: name is already used by an existing object 

Favor verificar a situação e proceder conforme a necessidade e encaminhar atividade 671 para G_UNJINFRA, com as alterações e informar o responsável para ajuste no pacote.

Obs: Já estão sendo utilizados os scripts atualizados do TFS.'''


print(summarize(s2))

# %%
s3 = '''
Prezados, a rotina sajIntegracoesTribunal_Ajuizamento localizada no servidor 10.200.11.200, está apresentando o seguinte erro no retorno do XML:

Método: 
AntesDeInserir

   ORA-01438: value larger than specified precision allowed for this column;

Método:
ServicoEnvioMensagensPendentes

   -9997|Ocorreu o seguinte erro na entidade Log Mensagens WS: Erro não cadastrado do Banco de Dados. Código de Erro - Nativo: 1438. Mensagem do Banco - ORA-01438: value larger than specified precision allowed for this column Entre em contato com o administrador do sistema.;


Verifiquei que o último UPDATE do sistema, é na tabela EPADCODIGO:

UPDATE 
  /*+ rule */ SAJ.EPADCODIGO 
SET 
  nuChave =10126 
WHERE 
   nmTabela =ESPJWSMENSAGEMLOG AND
   vlChave1=4 AND
   vlChave2=67076238 AND
    vlChave3 =  ;

E o último INSERT antes do erro é justamente na ESPJWSMENSAGEMLOG, tentando inserir APENAS o texto Banco de Dados em manutenção:

    insert into SAJ.ESPJWSMENSAGEMLOG ( CDWEBSERVICES ,CDMENSAGEM ,NUSEQENVIO ,DTPROCESSAMENTO ,CDRETORNO ,DERETORNO ) values ( 4 ,67076238 ,10126 ,to_date(28/11/2016 17:06:28,DD/MM/YYYY HH24:MI:SS) ,92 ,Banco de Dados em manutenção);

Segue anexo o log do erro:'''


print(summarize(s3))
# Out:
# Mensagem do Banco - ORA-01438: value larger than specified precision allowed for this column Entre em contato com o administrador do sistema.;
# Verifiquei que o último UPDATE do sistema, é na tabela EPADCODIGO:
# E o último INSERT antes do erro é justamente na ESPJWSMENSAGEMLOG, tentando inserir APENAS o texto Banco de Dados em manutenção:
# insert into SAJ.ESPJWSMENSAGEMLOG ( CDWEBSERVICES ,CDMENSAGEM ,NUSEQENVIO ,DTPROCESSAMENTO ,CDRETORNO ,DERETORNO ) values ( 4 ,67076238 ,10126 ,to_date(28/11/2016 17:06:28,DD/MM/YYYY HH24:MI:SS) ,92 ,Banco de Dados em manutenção);

# %%
s4 = '''
Erro na execução do Script SP4000125.DH4

Ao executar o script acima ocasionou o erro abaixo:


02/02/2018 04:25:52.687         ANALISING_SCRIPTS       SPJTINT        saj CaproniCA3.exe - Versao 1.1.22
02/02/2018 04:25:52.691         ANALISING_SCRIPTS       SPJTINT        saj Carregando o arquivo C:\CaproniCa3\bin\192.168.226.151\INPUT\SPJTINT\SP4000125.DH4
02/02/2018 04:25:52.698         ANALISING_SCRIPTS       SPJTINT        saj Validando C:\CaproniCa3\bin\192.168.226.151\INPUT\SPJTINT\SP4000125.DH4
02/02/2018 04:25:52.699         ANALISING_SCRIPTS       SPJTINT        saj OK

02/02/2018 04:26:51.735        RUNNING_DB_SCRIPTS       SPJTINT        saj CaproniCA3.exe - Versao 1.1.22
02/02/2018 04:26:51.741        RUNNING_DB_SCRIPTS       SPJTINT        saj Carregando o arquivo C:\CaproniCa3\bin\192.168.226.151\INPUT\SPJTINT\SP4000125.DH4
02/02/2018 04:26:51.748        RUNNING_DB_SCRIPTS       SPJTINT        saj Executando C:\CaproniCa3\bin\192.168.226.151\INPUT\SPJTINT\SP4000125.DH4
02/02/2018 04:26:51.750        RUNNING_DB_SCRIPTS       SPJTINT        saj Progresso: (1/3)
02/02/2018 04:26:51.773        RUNNING_DB_SCRIPTS       SPJTINT        saj Nao foi possivel executar o script SP4000125.DH4 na base SPJTINT. O statement: INSERT INTO SAJ.EPADCONFIGSERVIDOR (DEIPSERVIDOR, DENOMEAPLICATIVO, DECHAVE, DEVALOR, DEDESCRICAO)
VALUES (*, *, RPC.CONTROLAR_RECONEXAO, FALSE, Habilita o controle de reconexão.) apresentou o erro: ORA-00001: restrição exclusiva (SAJ.XPKEPADCONFIGSERVI) violada

Para Reproduzir basta Executar o script através do Caproni na base abaixo:

SPJXPSC = 
  (DESCRIPTION = 
  (ADDRESS_LIST = 
      (ADDRESS =
        (PROTOCOL = TCP)
        (Host = 192.168.226.151)
        (Port = 1521)
       )
  )
  (CONNECT_DATA = (SID = SPJTINT) (SERVER = DEDICATED)
  )
)
'''
print(summarize(s4))
# Out:
# 02/02/2018 04:25:52.687         ANALISING_SCRIPTS       SPJTINT        saj CaproniCA3.exe - Versao 1.1.22
# in92.168.226.151\INPUT\SPJTINT\SP4000125.DH4
# in92.168.226.151\INPUT\SPJTINT\SP4000125.DH4
# in92.168.226.151\INPUT\SPJTINT\SP4000125.DH4

# %%
s5 = '''

O sistema não está mostrando publicações na tela de publicações aguardando distribuição, onde o tpacao na espjpublicdiario seja = N.

Analisamos esse processo e executando a consulta abaixo. Veja que ele está na base e portanto na tabela que você extraiu.


select * from saj.espjpublicdiario where  nuformatado = 1011519-80.2016.8.26.0361


Fazendo um filtro na tela do link de publicações aguardando distribuição, por tudo que foi disponibilizado no dia 04/04 o sistema faz a consulta abaixo:


SELECT
   cast(N as char(1)) as cc_Sel,
   P.dtPublicacao,
   P.nuSeqPublicacao,
   P.cdTribunal,
   P.deOrgao,
   P.nuPublicacao,
   P.nuPagina,
   P.nuFormatado,
   P.nuNaoFormatado,
   P.flNovaDistribuicao,
   P.nuProcOriginario,
   P.nuOrigNaoFormatado,
   P.detipoacao,
   P.nmparteativa,
   P.nmpartepassiva,
   P.tpacao,
   P.dtProcessamento,
   P.cdUsuarioDist,
   P.dtUsuarioDist,
   T.deTribunal as cc_deTribunal,
     as cc_nmUsuario,
   case when ((P.cdAto is null) and
   (P.cdProcessoCitacao is null)) then P when (P.cdAto is not null) then I else C end as cc_tipo,
   case when ((P.cdAto is null) and
   (P.cdProcessoCitacao is null)) then Publicação when (P.cdAto is not null) then Intimação Eletrônica else Citação Eletrônica end as cc_detipo,
   ProcPublicacao.nuProcesso as cc_nuProcesso,
   ProcPublicacao.cdProcesso as cc_cdProcesso,
   case P.tpacao when M then Movimentar\Cadastrar no PGE.Net when C then Cadastrar Processo when N then Nova Distribuição when I then Cadastrar Incidente/recurso when R then (CASE WHEN p.cdprocessocitacao IS NULL THEN Revisar Cadastro proveniente de intimação eletrônica ELSE Revisar Cadastro proveniente de citação eletrônica END) end as cc_deAcao,
   A.deTipoAcao as cc_deTipoAcao,
  cast (null as character(1999 )) as dePublicacao
FROM
  SAJ.ESPJPUBLICDIARIO P
   JOIN SAJ.ESPJTRIBUNAL T ON
     P.cdTribunal = T.cdTribunal
   LEFT OUTER JOIN SAJ.ESPJPROCESSO PROCPUBLICACAO ON
     P.cdProcesso = ProcPublicacao.cdprocesso
   LEFT OUTER JOIN SAJ.ESPJTIPOACAO A ON
     ProcPublicacao.cdTipoAcao = A.cdTipoAcao
WHERE
   P.tpAcao <> N and
   P.dtProcessamento is null and
   P.dtpublicacao >= :dtInicio and
   P.dtpublicacao <= :dtFim and
  P.cdUsuarioDist IS NULL
ORDER BY
    P.nuPublicacao
Params=([dtInicio,ftDateTime,04/10/2017][dtFim,ftDateTime,04/10/2017 23:59:59])

Fazendo um filtro por esse processo específico (1011519-80.2016.8.26.0361) o sistema não localiza porém mesmo não mostrando na base, ou seja, estamos com um problema no filtro, que justifica o que o Erick vinha relatando que não encontrava as publicações já disponibilizadas por e-mail. A questão não é que elas não eram enviadas e sim não mostradas na tela.

SELECT
   cast(N as char(1)) as cc_Sel,
   P.dtPublicacao,
   P.nuSeqPublicacao,
   P.cdTribunal,
   P.deOrgao,
   P.nuPublicacao,
   P.nuPagina,
   P.nuFormatado,
   P.nuNaoFormatado,
   P.flNovaDistribuicao,
   P.nuProcOriginario,
   P.nuOrigNaoFormatado,
   P.detipoacao,
   P.nmparteativa,
   P.nmpartepassiva,
   P.tpacao,
   P.dtProcessamento,
   P.cdUsuarioDist,
   P.dtUsuarioDist,
   T.deTribunal as cc_deTribunal,
     as cc_nmUsuario,
   case when ((P.cdAto is null) and
   (P.cdProcessoCitacao is null)) then P when (P.cdAto is not null) then I else C end as cc_tipo,
   case when ((P.cdAto is null) and
   (P.cdProcessoCitacao is null)) then Publicação when (P.cdAto is not null) then Intimação Eletrônica else Citação Eletrônica end as cc_detipo,
   ProcPublicacao.nuProcesso as cc_nuProcesso,
   ProcPublicacao.cdProcesso as cc_cdProcesso,
   case P.tpacao when M then Movimentar\Cadastrar no PGE.Net when C then Cadastrar Processo when N then Nova Distribuição when I then Cadastrar Incidente/recurso when R then (CASE WHEN p.cdprocessocitacao IS NULL THEN Revisar Cadastro proveniente de intimação eletrônica ELSE Revisar Cadastro proveniente de citação eletrônica END) end as cc_deAcao,
   A.deTipoAcao as cc_deTipoAcao,
  cast (null as character(1999 )) as dePublicacao
FROM
  SAJ.ESPJPUBLICDIARIO P
   JOIN SAJ.ESPJTRIBUNAL T ON
     P.cdTribunal = T.cdTribunal
   LEFT OUTER JOIN SAJ.ESPJPROCESSO PROCPUBLICACAO ON
     P.cdProcesso = ProcPublicacao.cdprocesso
   LEFT OUTER JOIN SAJ.ESPJTIPOACAO A ON
     ProcPublicacao.cdTipoAcao = A.cdTipoAcao
WHERE
   ( P.tpAcao <> N and
   P.dtProcessamento is null and
   P.dtpublicacao >= :dtInicio and
   P.dtpublicacao <= :dtFim and
   P.cdUsuarioDist IS NULL ) and
  ( UPPER ( P . nuFormatado ) LIKE :NUFORMATADO )
ORDER BY
    P.nuPublicacao
Params=([dtInicio,ftDateTime,04/10/2017][dtFim,ftDateTime,04/10/2017 23:59:59][NUFORMATADO,ftString,%1011519-80.2016.8.26.0361%])

'''

print(summarize(s5))
# Out:
# O sistema não está mostrando publicações na tela de publicações aguardando distribuição, onde o tpacao na espjpublicdiario seja = N.
# select * from saj.espjpublicdiario where  nuformatado = 1011519-80.2016.8.26.0361
# Fazendo um filtro na tela do link de publicações aguardando distribuição, por tudo que foi disponibilizado no dia 04/04 o sistema faz a consulta abaixo:
# case when ((P.cdAto is null) and
# case when ((P.cdAto is null) and
# case P.tpacao when M then Movimentar\Cadastrar no PGE.Net when C then Cadastrar Processo when N then Nova Distribuição when I then Cadastrar Incidente/recurso when R then (CASE WHEN p.cdprocessocitacao IS NULL THEN Revisar Cadastro proveniente de intimação eletrônica ELSE Revisar Cadastro proveniente de citação eletrônica END) end as cc_deAcao,
# ...

# %%
s6 = '''

Descrição do problema:
Cliente: OSASCO 
Base: 0055 
Servidor de Aplicação: FLNSRVUNJ4017 
Versão: 4.23.0-57
Módulo: Execução fiscal
Usuário: DLANDRADE55

Ao tentar gerar o kit o sistema retorna a mensagem de erro: erro: Invalid variant type conversion: Erro geral na geração de processos a partir de CDAs

o erro ocorre apenas com os devedores abaixo

Devedor: Jose Salomao filho 
CDA:0005810; 0011429; 0014456

Devedor: Flavio Vagner Moares da Silva
CDA:002776,0018695,009445,002361,0008726

----------------------------
segue por anexo log do servidor, video 

SQL coletado pelo SPMONITOR 

SELECT 
  prm.* 
FROM 
   (SELECT 
      KD.cdKitGeracao,
      KD.sgTipoDocumento,
      KD.nuDocumento,
      KD.nuSeqKitDevGeracao,
      KG.flAgendado,
      KG.flExtraJudicial,
      GE.cdErro as CC_cdErro,
      GE.deDetalheErro as CC_deDetalheErro,
      KD.dtGeracaoProc,
      KG.dtVencDocArrec,
      KG.cdModeloCorresp,
     KG.tpGeracaoProcesso as cc_tpGeracaoProcesso 
   FROM 
     SAJ.ESPJKITDEVGERACAO KD 
      JOIN SAJ.ESPJKITGERACAO KG ON 
        KD.cdKitGeracao = KG.cdKitGeracao 
      LEFT OUTER JOIN SAJ.ESPJGERACAOERRO GE ON 
         GE.CDKITGERACAO = KD.CDKITGERACAO AND
        GE.NUSEQKITDEVGERACAO = KD.NUSEQKITDEVGERACAO 
   WHERE 
     NOT EXISTS(select cdAgendamento 
   FROM 
     SAJ.ESPJAGENDINTERROMP 
   WHERE 
      KG.cdAgendamento = cdAgendamento ) and
   KG.dtCancelamento is null and
   KD.cdProcesso is null and
   KD.dtGeracaoProc is null and
   GE.cdErro is null and
   KD.flProcessandoDev = :pflProcessandoDev and
   KG.dtFimProcessamento is null and
   KD.cdKitGeracao = :prmCdKitGeracao and
  KG.flAgendado = :pflAgendado 
ORDER BY 
  KG.dtUsuInclusao asc ) prm 
WHERE 
    RowNum <= :pnPrimeiros Params=([pflProcessandoDev,ftString,N][prmCdKitGeracao,ftFloat,419][pflAgendado,ftString,N][pnPrimeiros,ftInteger,1])

'''

print(summarize(s6))
# Out:
# JOIN SAJ.ESPJKITGERACAO KG ON
# LEFT OUTER JOIN SAJ.ESPJGERACAOERRO GE ON
# KG.dtCancelamento is null and
# KD.cdProcesso is null and
# KD.dtGeracaoProc is null and
# GE.cdErro is null and
# KG.dtFimProcessamento is null and
# KD.cdKitGeracao = :prmCdKitGeracao and
# KG.flAgendado = :pflAgendado
# RowNum <= :pnPrimeiros Params=([pflProcessandoDev,ftString,N][prmCdKitGeracao,ftFloat,419][pflAgendado,ftString,N][pnPrimeiros,ftInteger,1])
